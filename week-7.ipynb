# %% [markdown]
# <a href="https://colab.research.google.com/github/eyv7jz/ds1002-eyv7jz/blob/main/week-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 7
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL for your notebook for review.
#
# Load the following dataset into pandas and perform the requested operations in code.
#
# Source: https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv

# %%
# Load pandas and the data
import numpy as np
import pandas as pd
ride = pd.read_csv("ride_sharing.csv")
ride
# Out:
#          duration  station_A_id  \
# 0      12 minutes            81
# 1      24 minutes             3
# 2       8 minutes            67
# 3       4 minutes            16
# 4      11 minutes            22
# ...           ...           ...
# 25755  11 minutes            15
# 25756  10 minutes            15
# 25757  14 minutes            15
# 25758  14 minutes            15
# 25759  29 minutes            16
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 1           Powell St BART Station (Market St at 4th St)           118
# 2      San Francisco Caltrain Station 2  (Townsend St...            23
# 3                                Steuart St at Market St            28
# 4                                  Howard St at Beale St           350
# ...                                                  ...           ...
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# ...

# %%
# show how many rows and columns are in this dataset
ride.shape
# Out:
# (25760, 10)

# %%
# The first column, "duration" is seen as a string.
# Using two snippets of code, clean this column up so that
# is now an integer (int64)
ride['duration'] = ride['duration'].str.strip('minutes')
ride['duration'] = ride['duration'].astype('int')

# %%
# Now display the datatypes in the updated dataframe
ride
# Out:
#        duration  station_A_id  \
# 0            12            81
# 1            24             3
# 2             8            67
# 3             4            16
# 4            11            22
# ...         ...           ...
# 25755        11            15
# 25756        10            15
# 25757        14            15
# 25758        14            15
# 25759        29            16
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 1           Powell St BART Station (Market St at 4th St)           118
# 2      San Francisco Caltrain Station 2  (Townsend St...            23
# 3                                Steuart St at Market St            28
# 4                                  Howard St at Beale St           350
# ...                                                  ...           ...
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# ...

# %%
# Show the min and max values of ride durations (the shortest and longest rides)
# Hint: If 'df' is the name of your dataframe, simply specify the column name
# and then append the .min() or .max() methods.
print(ride.duration.min(), ride.duration.max())
# Out:
# 1 1372

# %%
# Create a new dataframe object and populate it with rides that are 60 minutes or less.
# Hint: Use the .query() method for the dataframe that we used in class.
new_ride = ride.query('duration <= 10')
new_ride
# Out:
#        duration  station_A_id  \
# 2             8            67
# 3             4            16
# 5            10            22
# 7             9            30
# 9             5            30
# ...         ...           ...
# 25744         4            21
# 25746         4            21
# 25753         9            21
# 25754         9            21
# 25756        10            15
#
#                                           station_A_name  station_B_id  \
# 2      San Francisco Caltrain Station 2  (Townsend St...            23
# 3                                Steuart St at Market St            28
# 5                                  Howard St at Beale St             6
# 7         San Francisco Caltrain (Townsend St at 4th St)            97
# 9         San Francisco Caltrain (Townsend St at 4th St)            62
# ...                                                  ...           ...
# 25744   Montgomery St BART Station (Market St at 2nd St)             3
# ...

# %%
# Now show both the min and max values of the duration column for your new dataset.
print(new_ride.duration.min(), new_ride.duration.max())
# Out:
# 1 10

# %%
# Using the new dataframe, update it so that it ONLY has records where
# the tire_size is 26.
ride.tire_size.min()
tire_ride = ride[ride['tire_size'] == 26]
tire_ride
# Out:
#        duration  station_A_id  \
# 0            12            81
# 3             4            16
# 6            16            67
# 9             5            30
# 12            7             3
# ...         ...           ...
# 25750        15            16
# 25751        15            16
# 25755        11            15
# 25756        10            15
# 25757        14            15
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 3                                Steuart St at Market St            28
# 6      San Francisco Caltrain Station 2  (Townsend St...           107
# 9         San Francisco Caltrain (Townsend St at 4th St)            62
# 12          Powell St BART Station (Market St at 4th St)            27
# ...                                                  ...           ...
# 25750                            Steuart St at Market St           371
# ...

# %%
# Finally, produce a count of all records with FEMALE riders
# using the 26-inch wheeled rental bikes for their rentals of
# one hour or less.
hour_ride = tire_ride[ride['duration'] <= 60]
female_ride = hour_ride[ride['user_gender'] == "Female"]
female_ride
# Out:
# <ipython-input-46-af581fcd457c>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   hour_ride = tire_ride[ride['duration'] <= 60]
# <ipython-input-46-af581fcd457c>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_ride = hour_ride[ride['user_gender'] == "Female"]
#        duration  station_A_id  \
# 18           16            16
# 41           12             3
# 45            1            67
# 52           13            21
# 53           14            21
# ...         ...           ...
# 25703         5             5
# 25709        29             5
# 25726        13             3
# 25732        24             5
# 25733        21             5
#
#                                           station_A_name  station_B_id  \
# 18                               Steuart St at Market St            42
# 41          Powell St BART Station (Market St at 4th St)             6
# ...
