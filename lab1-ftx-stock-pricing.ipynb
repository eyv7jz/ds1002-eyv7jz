# %% [markdown]
# <a href="https://colab.research.google.com/github/eyv7jz/ds1002-eyv7jz/blob/main/lab1-ftx-stock-pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS1002 Lab 1: Python
#
# In this lab you will work with a dataset, writing python to generate the deliverables specified in the cells below.
#
# > **FTX** was a cryptocurrency exchange founded by Sam Bankman-Fried that saw both a spectacular rise and collapse between 2021 and 2022. At one point it had a valuation of $32B. Bankman-Fried was recently found guilty on seven counts of fraud and conspiracy.
#
# The dataset for this assignment covers that rise and fall from the viewpoint of daily stock closing prices for FTX (ticker symbol `FTT`).
#
# Answer the questions below with the appropriate Python code. Point assignments are indicated for each section. There are 15 total points possible for this lab, which counts as 5% of your overall grade. There is a 1-point extra credit option at the end.
#
# Useful reference material:
# - [Pandas Review](https://colab.research.google.com/github/nmagee/ds1002/blob/main/notebooks/pandas-review.ipynb) notebook.
# - [Charts Reference](https://colab.research.google.com/github/nmagee/ds1002/blob/main/notebooks/charts-in-colaboratory.ipynb) notebook.
# - [Plots Walkthrough](https://colab.research.google.com/github/nmagee/ds1002/blob/main/notebooks/plotting-examples.ipynb)

# %% [markdown]
# ## Group Submissions
#
# If you are working in a group to complete this lab, you may have no more than 3 members to a group. Group members should be indicated in the cell below -- list both names and UVA computing IDs.
#
# Each student should then submit **the same URL** for the lab in Canvas. (If a group has Member1, Member2, and Member3, only one member needs to save the completed work back to GitHub and all members should submit that URL for grading.)

# %%
# List group members (if applicable). Identify names and computing IDs
#
# Name                    Computing ID
# I'm not in a group.

# %% [markdown]
# ## 1. Load Libraries & Data (3 pts)
#
# https://s3.amazonaws.com/ds1002-resources/data/ftx-2021-01-01--2023-12-31.csv
#
# Import any necessary libraries and load the remote CSV file below into a DataFrame. Resolve any import issues you need to.

# %%
import numpy as np
import pandas as pd
ftx = pd.read_csv('ftx-2021-01-01--2023-12-31.csv', sep=';')
ftx
# Out:
#                      timeOpen                 timeClose  \
# 0    2022-12-31T00:00:00.000Z  2022-12-31T23:59:59.999Z
# 1    2022-12-30T00:00:00.000Z  2022-12-30T23:59:59.999Z
# 2    2022-12-29T00:00:00.000Z  2022-12-29T23:59:59.999Z
# 3    2022-12-28T00:00:00.000Z  2022-12-28T23:59:59.999Z
# 4    2022-12-27T00:00:00.000Z  2022-12-27T23:59:59.999Z
# ..                        ...                       ...
# 736  2021-01-06T00:00:00.000Z  2021-01-06T23:59:59.999Z
# 737  2021-01-05T00:00:00.000Z  2021-01-05T23:59:59.999Z
# 738  2021-01-04T00:00:00.000Z  2021-01-04T23:59:59.999Z
# 739  2021-01-03T00:00:00.000Z  2021-01-03T23:59:59.999Z
# 740  2021-01-03T00:00:00.000Z  2021-01-03T23:59:59.999Z
#
#                      timeHigh                   timeLow      open      high  \
# 0    2022-12-31T15:23:00.000Z  2022-12-31T00:21:00.000Z  0.838968  0.853502
# 1    2022-12-30T04:22:00.000Z  2022-12-30T15:12:00.000Z  0.860193  0.864752
# 2    2022-12-29T00:49:00.000Z  2022-12-29T21:03:00.000Z  0.885723  0.887118
# 3    2022-12-28T00:20:00.000Z  2022-12-28T10:44:00.000Z  0.921162  0.925702
# 4    2022-12-27T14:19:00.000Z  2022-12-27T19:12:00.000Z  0.931138  0.955402
# ..                        ...                       ...       ...       ...
# 736  2021-01-06T23:59:03.000Z  2021-01-06T01:41:03.000Z  8.671285  9.390797
# 737  2021-01-05T22:44:03.000Z  2021-01-05T06:19:03.000Z  7.528216  8.714947
# 738  2021-01-04T06:40:03.000Z  2021-01-04T10:18:03.000Z  6.948680  7.632146
# 739  2021-01-03T16:25:03.000Z  2021-01-03T00:25:03.000Z  6.201133  7.007523
# 740  2021-01-03T16:25:03.000Z  2021-01-03T00:25:03.000Z  6.201133  7.007523
#
#           low     close       volume     marketCap                 timestamp
# 0    0.835226  0.842688   3001502.06  2.771561e+08  2022-12-31T23:59:59.999Z
# 1    0.826643  0.839048   3608615.07  2.759588e+08  2022-12-30T23:59:59.999Z
# 2    0.843029  0.860231   3766979.57  2.829258e+08  2022-12-29T23:59:59.999Z
# 3    0.869842  0.886091   4192949.85  2.914310e+08  2022-12-28T23:59:59.999Z
# 4    0.916414  0.923668   4574953.05  3.037898e+08  2022-12-27T23:59:59.999Z
# ..        ...       ...          ...           ...                       ...
# 736  8.425946  9.390797  31404627.93  8.859932e+08  2021-01-06T23:59:59.999Z
# 737  7.081120  8.664688  49479278.39  8.174869e+08  2021-01-05T23:59:59.999Z
# 738  6.358218  7.514079  40526109.15  7.089305e+08  2021-01-04T23:59:59.999Z
# 739  6.171834  6.923968  31046652.87  6.532553e+08  2021-01-03T23:59:59.999Z
# 740  6.171834  6.923968  31046652.87  6.532553e+08  2021-01-03T23:59:59.999Z
#
# [741 rows x 11 columns]

# %% [markdown]
# ## 2. Get Summary Data (1 pt)

# %% [markdown]
# In code, display how many rows and columns are in the raw dataset.

# %%
ftx.shape
# Out:
# (741, 11)

# %% [markdown]
# ## 3. Clean and Organize the Data (3 pts)
#
# Check for data quality.
#
# - Resolve any empty values or duplicate rows.
# - Order the data properly if necessary.
# - Drop the following columns and save the dataframe: `timeOpen`, `timeClose`, `timeHigh`, `timeLow`, `marketCap`,

# %%
ftx.duplicated().sum()
ftx = ftx.drop_duplicates()
ftx.duplicated().sum() == 0    # came back as true
ftx.isna().sum() == 0     # came back as true for all columns
ftx = ftx.sort_values(by='timestamp')
ftx = ftx.reset_index()
ftx = ftx = ftx.drop(columns=["timeOpen","timeClose","timeHigh","timeLow","marketCap","index"])

# %% [markdown]
# Now display the first 10 rows of the cleaned dataset.

# %%
ftx_10_rows = ftx.iloc[0:10]
ftx_10_rows
# Out:
#        open       high       low     close        volume  \
# 0  6.201133   7.007523  6.171834  6.923968  3.104665e+07
# 1  6.948680   7.632146  6.358218  7.514079  4.052611e+07
# 2  7.528216   8.714947  7.081120  8.664688  4.947928e+07
# 3  8.671285   9.390797  8.425946  9.390797  3.140463e+07
# 4  9.386493  10.004872  9.215244  9.562131  4.630334e+07
# 5  9.569239   9.726429  8.452265  9.380988  4.228627e+07
# 6  9.370450   9.636120  8.728044  9.570511  2.849895e+07
# 7  9.571917   9.944797  8.657147  9.308809  3.101239e+07
# 8  9.298315   9.298315  7.126050  8.610997  1.013024e+08
# 9  8.615143   9.097479  8.040916  8.381133  2.674536e+07
#
#                   timestamp
# 0  2021-01-03T23:59:59.999Z
# 1  2021-01-04T23:59:59.999Z
# 2  2021-01-05T23:59:59.999Z
# 3  2021-01-06T23:59:59.999Z
# 4  2021-01-07T23:59:59.999Z
# 5  2021-01-08T23:59:59.999Z
# 6  2021-01-09T23:59:59.999Z
# 7  2021-01-10T23:59:59.999Z
# 8  2021-01-11T23:59:59.999Z
# 9  2021-01-12T23:59:59.999Z

# %% [markdown]
# ## 4. Calculate Daily Gains/Losses (2 pts)

# %% [markdown]
# Using Pandas, add a new column named `["close_change"]` to the dataframe that calculates the difference between daily closing prices for FTX. This will result in positive (growth) and negative (loss) values.
#
# Note:
# - Be careful about how you calculate this. Each row should calculate that difference from the row above it, which must be the previous calendar day.
# - Reference code for this is available in the [Pandas Review](https://colab.research.google.com/github/nmagee/ds1002/blob/main/notebooks/pandas-review.ipynb) notebook. Hint: It is not complicated and does not require a for-loop.

# %%
ftx['close_change'] = ftx['close'].diff()
ftx
# Out:
#          open       high       low     close       volume  \
# 0    6.201133   7.007523  6.171834  6.923968  31046652.87
# 1    6.948680   7.632146  6.358218  7.514079  40526109.15
# 2    7.528216   8.714947  7.081120  8.664688  49479278.39
# 3    8.671285   9.390797  8.425946  9.390797  31404627.93
# 4    9.386493  10.004872  9.215244  9.562131  46303336.73
# ..        ...        ...       ...       ...          ...
# 722  0.931138   0.955402  0.916414  0.923668   4574953.05
# 723  0.921162   0.925702  0.869842  0.886091   4192949.85
# 724  0.885723   0.887118  0.843029  0.860231   3766979.57
# 725  0.860193   0.864752  0.826643  0.839048   3608615.07
# 726  0.838968   0.853502  0.835226  0.842688   3001502.06
#
#                     timestamp  close_change
# 0    2021-01-03T23:59:59.999Z           NaN
# 1    2021-01-04T23:59:59.999Z      0.590111
# 2    2021-01-05T23:59:59.999Z      1.150608
# 3    2021-01-06T23:59:59.999Z      0.726110
# 4    2021-01-07T23:59:59.999Z      0.171334
# ..                        ...           ...
# 722  2022-12-27T23:59:59.999Z     -0.007028
# 723  2022-12-28T23:59:59.999Z     -0.037577
# 724  2022-12-29T23:59:59.999Z     -0.025860
# 725  2022-12-30T23:59:59.999Z     -0.021183
# 726  2022-12-31T23:59:59.999Z      0.003640
#
# [727 rows x 7 columns]

# %% [markdown]
# ## 5. Identify Growth Days (1 pt)

# %% [markdown]
# Based on the daily change in closing prices calculated above, identify the top 10 days of positive growth for FTX.
#
# Display your results in a table showing both the rate of change and their dates.

# %%
top_10 = ftx['close_change'].nlargest(10)
top_10_indexes = ftx['close_change'].nlargest(10).index
top_10_ts = ftx.loc[top_10_indexes, 'timestamp']
ftx_top_10 = {
    'close_change' : top_10,
    'timestamp' : top_10_ts
}
ftx_df = pd.DataFrame(ftx_top_10)
ftx_df = ftx_df.sort_values(by='timestamp')
ftx_df
# Out:
#      close_change                 timestamp
# 47       8.335900  2021-02-19T23:59:59.999Z
# 65       5.529699  2021-03-09T23:59:59.999Z
# 113      4.504385  2021-04-26T23:59:59.999Z
# 122      4.488174  2021-05-05T23:59:59.999Z
# 141      6.333923  2021-05-24T23:59:59.999Z
# 218      5.325192  2021-08-09T23:59:59.999Z
# 241     16.677156  2021-09-01T23:59:59.999Z
# 246      9.800320  2021-09-06T23:59:59.999Z
# 248      5.239728  2021-09-08T23:59:59.999Z
# 420      4.401841  2022-02-28T23:59:59.999Z

# %% [markdown]
# ## 6. Calculate the % Rate of Change (2 pts)

# %% [markdown]
# Next, create a new column named `["rate_of_change"]` based on `["close_change"]`.
#
# Use the Pandas Review notebook for reference. Again, this is an easy operation in Pandas and does not require a for-loop.

# %%
ftx['rate_of_change'] = ftx['close_change'].pct_change()
ftx
# Out:
#          open       high       low     close       volume  \
# 0    6.201133   7.007523  6.171834  6.923968  31046652.87
# 1    6.948680   7.632146  6.358218  7.514079  40526109.15
# 2    7.528216   8.714947  7.081120  8.664688  49479278.39
# 3    8.671285   9.390797  8.425946  9.390797  31404627.93
# 4    9.386493  10.004872  9.215244  9.562131  46303336.73
# ..        ...        ...       ...       ...          ...
# 722  0.931138   0.955402  0.916414  0.923668   4574953.05
# 723  0.921162   0.925702  0.869842  0.886091   4192949.85
# 724  0.885723   0.887118  0.843029  0.860231   3766979.57
# 725  0.860193   0.864752  0.826643  0.839048   3608615.07
# 726  0.838968   0.853502  0.835226  0.842688   3001502.06
#
#                     timestamp  close_change  rate_of_change
# 0    2021-01-03T23:59:59.999Z           NaN             NaN
# 1    2021-01-04T23:59:59.999Z      0.590111             NaN
# 2    2021-01-05T23:59:59.999Z      1.150608        0.949817
# 3    2021-01-06T23:59:59.999Z      0.726110       -0.368934
# 4    2021-01-07T23:59:59.999Z      0.171334       -0.764039
# ..                        ...           ...             ...
# 722  2022-12-27T23:59:59.999Z     -0.007028       -1.195015
# 723  2022-12-28T23:59:59.999Z     -0.037577        4.346593
# 724  2022-12-29T23:59:59.999Z     -0.025860       -0.311817
# 725  2022-12-30T23:59:59.999Z     -0.021183       -0.180850
# 726  2022-12-31T23:59:59.999Z      0.003640       -1.171848
#
# [727 rows x 8 columns]

# %% [markdown]
# ## 7. Identify Greatest % Change Days (1 pt)

# %% [markdown]
# Based on the rate change column calculated above, identify the top 5 days of greatest rate changes, whether positive or negative.
#
# Display your results in a table showing both the rate of change and their dates.

# %%
top_5 = abs(ftx['rate_of_change']).nlargest(5)
top_5_indexes = abs(ftx['rate_of_change']).nlargest(5).index
top_5_ts = ftx.loc[top_5_indexes, 'timestamp']

ftx_top_5 = {
    'rate_of_change' : top_5,
    'timestamp' : top_5_ts
}
ftx_df = pd.DataFrame(ftx_top_5)
ftx_df = ftx_df.sort_values(by='timestamp')
ftx_df
# Out:
#      rate_of_change                 timestamp
# 288      262.744729  2021-10-18T23:59:59.999Z
# 359      612.326740  2021-12-28T23:59:59.999Z
# 494      117.908853  2022-05-13T23:59:59.999Z
# 540      164.238246  2022-06-28T23:59:59.999Z
# 673      129.835551  2022-11-08T23:59:59.999Z

# %% [markdown]
# ## 8. Plot the Data (2 pts)

# %% [markdown]
# Finally, create two separate plots of the data -- one for the daily closing price and one for the daily gains/losses. These can be histograms or line plots.

# %%
import matplotlib.pyplot as plt

plt.plot(ftx['close'], color='c')
plt.title('Daily Closing Price')
plt.xlabel('Day Number/Index')
plt.ylabel('Closing Price')
plt.show()

plt.plot(ftx['close_change'], color='m')
plt.title('Daily Gains/Losses')
plt.xlabel('Day Number/Index')
plt.ylabel('Gains/Losses')
plt.show()

# %% [markdown]
# ## BONUS! (1 pt)

# %% [markdown]
# Combine the two plots from #8 above into a single plot, displaying both together. Your plot should have two Y-axis scales, should differentiate the two values by color, and should include a legend.

# %%
fig, ax1 = plt.subplots()
ax1.plot(ftx['close_change'], color='orange', label='Daily Gains/Losses')
ax1.set_ylabel('Gains/Losses', color='orange')
ax1.set_xlabel('Day Number/Index')

ax2 = ax1.twinx()
ax2.plot(ftx['close'], color='navy', label='Daily Closing Price')
ax2.set_ylabel('Closing Price', color='navy')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
