# %% [markdown]
# <a href="https://colab.research.google.com/github/eyv7jz/ds1002-eyv7jz/blob/main/Class_Practice_9_22_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info()
#get basic info about the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get the head rows - whateer number I want
mock_data.head(3)
# Out:
#    id first_name  last_name                  email  gender  age
# 0   1      Deane      Fitch     dfitch0@senate.gov    Male   36
# 1   2    Adaline  Halvorsen    ahalvorsen1@msn.com  Female   54
# 2   3    Raymond     Badger  rbadger2@marriott.com    Male   84

# %%
mock_data.tail()
# Out:
#        id first_name  last_name                          email gender  age
# 995   996    Shelden    Sprules        ssprulesrn@redcross.org   Male   82
# 996   997     Harlin  St. Aubyn        hstaubynro@e-recht24.de   Male   85
# 997   998     Sterne     Loghan        sloghanrp@clickbank.net   Male   42
# 998   999   Langston   Chalmers  lchalmersrq@elegantthemes.com   Male   11
# 999  1000        Ric     Densun      rdensunrr@photobucket.com   Male   23

# %%
#grab a specific row from a df
mock_data.loc[9]
# Out:
# id                             10
# first_name                 Sholom
# last_name                McFayden
# email         smcfayden9@sohu.com
# gender                       Male
# age                            51
# Name: 9, dtype: object

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    44.022000
# std     288.819436    26.264183
# min       1.000000     1.000000
# 25%     250.750000    20.750000
# 50%     500.500000    43.000000
# 75%     750.250000    67.000000
# max    1000.000000    90.000000

# %%
#get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
#can only rename one thing at a time, so in this case columns
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id    fname      lname                  email  gender  age
# 0   1    Deane      Fitch     dfitch0@senate.gov    Male   36
# 1   2  Adaline  Halvorsen    ahalvorsen1@msn.com  Female   54
# 2   3  Raymond     Badger  rbadger2@marriott.com    Male   84
# 3   4  Griffin  Curgenuer  gcurgenuer3@yahoo.com    Male   14
# 4   5     Boyd      Murty        bmurty4@ihg.com    Male   30

# %%
#asks for one column
mock_data["fname"]
# Out:
# 0         Deane
# 1       Adaline
# 2       Raymond
# 3       Griffin
# 4          Boyd
#          ...
# 995     Shelden
# 996      Harlin
# 997      Sterne
# 998    Langston
# 999         Ric
# Name: fname, Length: 1000, dtype: object

# %%
#asks the same thing as above
mock_data.fname
# Out:
# 0         Deane
# 1       Adaline
# 2       Raymond
# 3       Griffin
# 4          Boyd
#          ...
# 995     Shelden
# 996      Harlin
# 997      Sterne
# 998    Langston
# 999         Ric
# Name: fname, Length: 1000, dtype: object

# %%
#asks for two columns
mock_data[["fname","lname"]]
# Out:
#         fname      lname
# 0       Deane      Fitch
# 1     Adaline  Halvorsen
# 2     Raymond     Badger
# 3     Griffin  Curgenuer
# 4        Boyd      Murty
# ..        ...        ...
# 995   Shelden    Sprules
# 996    Harlin  St. Aubyn
# 997    Sterne     Loghan
# 998  Langston   Chalmers
# 999       Ric     Densun
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data["gender"]).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(["gender"])["age"].mean()
# Out:
# gender
# Agender        39.333333
# Bigender       42.363636
# Female         44.120455
# Genderfluid    47.200000
# Genderqueer    48.928571
# Male           43.895397
# Non-binary     44.266667
# Polygender     44.117647
# Name: age, dtype: float64
