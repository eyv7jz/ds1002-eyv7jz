# %% [markdown]
# <a href="https://colab.research.google.com/github/eyv7jz/ds1002-eyv7jz/blob/main/data-cleaning-student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Data Cleaning Practice
#
# You'll be working with bicycle ride sharing data in San Francisco called `ride_sharing.csv`.
#
# It contains information on the start and end stations, the trip duration, and some user information for a bike sharing service.

# %%
# import dependencies
import pandas as pd

# %%
# import the csv
df = pd.read_csv("https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv")
df.head(13)
# Out:
#       duration  station_A_id  \
# 0   12 minutes            81
# 1   24 minutes             3
# 2    8 minutes            67
# 3    4 minutes            16
# 4   11 minutes            22
# 5   10 minutes            22
# 6   16 minutes            67
# 7    9 minutes            30
# 8   21 minutes            81
# 9    5 minutes            30
# 10  19 minutes            81
# 11   6 minutes             3
# 12   7 minutes             3
#
#                                        station_A_name  station_B_id  \
# 0                                  Berry St at 4th St           323
# 1        Powell St BART Station (Market St at 4th St)           118
# 2   San Francisco Caltrain Station 2  (Townsend St...            23
# 3                             Steuart St at Market St            28
# 4                               Howard St at Beale St           350
# 5                               Howard St at Beale St             6
# ...

# %%
len(df)
# Out:
# 25760

# %%
df.shape
# Out:
# (25760, 10)

# %%
# sort the df
# df.sort_values(by='column_name', ascending=True)

df.sort_values(by='station_A_id', ascending=True)
# Out:
#          duration  station_A_id                                station_A_name  \
# 10280   7 minutes             3  Powell St BART Station (Market St at 4th St)
# 18724  10 minutes             3  Powell St BART Station (Market St at 4th St)
# 3333    6 minutes             3  Powell St BART Station (Market St at 4th St)
# 18738   4 minutes             3  Powell St BART Station (Market St at 4th St)
# 18739   7 minutes             3  Powell St BART Station (Market St at 4th St)
# ...           ...           ...                                           ...
# 8645   18 minutes            81                            Berry St at 4th St
# 8646   21 minutes            81                            Berry St at 4th St
# 8648   11 minutes            81                            Berry St at 4th St
# 8619   16 minutes            81                            Berry St at 4th St
# 0      12 minutes            81                            Berry St at 4th St
#
# ...

# %%
df.sort_values(by='station_A_id', ascending=False)
# Out:
#          duration  station_A_id                                station_A_name  \
# 0      12 minutes            81                            Berry St at 4th St
# 5522    2 minutes            81                            Berry St at 4th St
# 18744  12 minutes            81                            Berry St at 4th St
# 18745  16 minutes            81                            Berry St at 4th St
# 18746   9 minutes            81                            Berry St at 4th St
# ...           ...           ...                                           ...
# 1701   12 minutes             3  Powell St BART Station (Market St at 4th St)
# 18877   3 minutes             3  Powell St BART Station (Market St at 4th St)
# 7329    9 minutes             3  Powell St BART Station (Market St at 4th St)
# 1699   30 minutes             3  Powell St BART Station (Market St at 4th St)
# 22682   9 minutes             3  Powell St BART Station (Market St at 4th St)
#
# ...

# %%
# view only the records based upon a given value of a given column
# look for all rows where station_A_id is equal to 81

# To do this, use the .query() method against your dataframe. As a parameter
# set
df.query("station_A_id == 81")
# Out:
#          duration  station_A_id      station_A_name  station_B_id  \
# 0      12 minutes            81  Berry St at 4th St           323
# 8      21 minutes            81  Berry St at 4th St            16
# 10     19 minutes            81  Berry St at 4th St            16
# 25      3 minutes            81  Berry St at 4th St            93
# 29      6 minutes            81  Berry St at 4th St           116
# ...           ...           ...                 ...           ...
# 25684   4 minutes            81  Berry St at 4th St            50
# 25700   1 minutes            81  Berry St at 4th St           364
# 25711   4 minutes            81  Berry St at 4th St            93
# 25712   3 minutes            81  Berry St at 4th St            93
# 25716   4 minutes            81  Berry St at 4th St           104
#
#                      station_B_name  bike_id  user_type  user_birth_year  \
# 0                Broadway at Kearny     5480          2             1959
# ...

# %%
df.query('user_gender == "Female"')
# Out:
#           duration  station_A_id  \
# 8       21 minutes            81
# 13     187 minutes            15
# 18      16 minutes            16
# 25       3 minutes            81
# 30       6 minutes            21
# ...            ...           ...
# 25716    4 minutes            81
# 25726   13 minutes             3
# 25732   24 minutes             5
# 25733   21 minutes             5
# 25736   13 minutes            21
#
#                                           station_A_name  station_B_id  \
# 8                                     Berry St at 4th St            16
# 13     San Francisco Ferry Building (Harry Bridges Pl...           355
# 18                               Steuart St at Market St            42
# 25                                    Berry St at 4th St            93
# 30      Montgomery St BART Station (Market St at 2nd St)           323
# ...                                                  ...           ...
# ...

# %% [markdown]
# The `user_type column` contains information on whether a user is taking a free ride and takes on the following values:
#
# `1` for free riders.
# `2` for pay per ride.
# `3` for monthly subscribers.
#
# **1. Provide summary statistics for the `user_type` columns**

# %%
from collections import Counter
count = Counter(df.user_type)
most_common = count.most_common(1)
print(most_common)
print(df.user_type.min())
print(df.user_type.max())
print(df.user_type.mean())
print(df.user_type.median())
print(len(df.user_type))
# Out:
# [(2, 12972)]
# 1
# 3
# 2.008385093167702
# 2.0
# 25760

# %% [markdown]
# **2. Find the average ride `duration`.**

# %%
df['duration'] = df['duration'].astype('str').str.strip(" minutes")
df['duration'] = df['duration'].astype('int')
df['duration'].mean()
# Out:
# 11.389052795031056

# %% [markdown]
# Bicycle tire sizes could be either 26″, 27″ or 29″ and are here correctly stored as a categorical value. In an effort to cut maintenance costs, the ride sharing provider decided to set the maximum tire size to be 27″.
#
# **3. Set the maximum tire size to 27" in the dataset**

# %%
df.loc[df['tire_size']> 27, 'tire_size'] = 27
assert df['tire_size'].max() <= 27
df
# Out:
#        duration  station_A_id  \
# 0            12            81
# 1            24             3
# 2             8            67
# 3             4            16
# 4            11            22
# ...         ...           ...
# 25755        11            15
# 25756        10            15
# 25757        14            15
# 25758        14            15
# 25759        29            16
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 1           Powell St BART Station (Market St at 4th St)           118
# 2      San Francisco Caltrain Station 2  (Townsend St...            23
# 3                                Steuart St at Market St            28
# 4                                  Howard St at Beale St           350
# ...                                                  ...           ...
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# ...
